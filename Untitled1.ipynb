# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import scipy.misc

# %%
img = plt.imread('quad_spe.jpg')

# %%
plt.imshow(img)

# %%
plt.hist(img.reshape(-1))
# Out:
# (array([6.25000e+02, 2.74650e+04, 8.42300e+03, 1.44900e+03, 1.26400e+03,
#         1.81600e+03, 1.69600e+03, 3.36939e+05, 6.76951e+05, 6.02000e+02]),
#  array([ 35. ,  56.2,  77.4,  98.6, 119.8, 141. , 162.2, 183.4, 204.6,
#         225.8, 247. ]),
#  <a list of 10 Patch objects>)

# %%
img_bw = img // 120
img_bw[img_bw!=0] = 1
img_bw*=255

# %%
plt.imshow(img_bw)

# %%
plt.hist(img_bw.reshape(-1))
# Out:
# (array([  37962.,       0.,       0.,       0.,       0.,       0.,
#               0.,       0.,       0., 1019268.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
plt.imsave('quad_spe.png',img_bw)
